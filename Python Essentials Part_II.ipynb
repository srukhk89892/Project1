# %% [markdown]
# # Python Operators

# %% [raw]
# Operators are special symbols in Python which are used to perform computations or certain checks on variables/values.

# %% [markdown]
# ## Arithmetic Operators
# These are the standard symbols for elementary operations.

# %%
a=5
b=2

# %%
#  Addition
c = a + b
print(c)

# %%
# The plus operator can help concatenate strings
x='Data'
y ='Science'
z = x + y
print(z)
# Out:
# DataScience

# %%
# Subtraction
c = b - a
print(c)
# Out:
# -2

# %%
# Multiplication
c = a * b
print(c)

# %%
# Power
a= 5
b = 3
c = a ** b
print(c)
# Out:
# 125

# %%
# Division
c = a / b
print(c)
# Out:
# 1.6666666666666667

# %%
# Modulo operator refers to the remainder after division
c = a % b
print(c)
# Out:
# 2

# %%
# Division(floor)
c = a // b
print(c)
# Out:
# 1

# %% [markdown]
# ## Comparison Operators
# Comparison returns a boolean value on evaluation.

# %%
x  = 20
y  = 30

print('Is  x  greater  than  y  :-  ',x>y)
print('Is  x  less  than    y  :-  ',x<y)
print('Is  x  equal  to    y  :-  ',x==y)
print('Is  x  not  equal  to  y  :-  ',x!=y)
print('Is  x  greater  than  or  equal  to  y  :-  ',x>=y)
print('Is  x  less  than  or  equal  to  y  :-  ',x<=y)

# %%
a = 'Data'
b = 'Science'
c = 'Data'

# %%
a == b

# %%
a ==c

# %%
a != b # Comparison operators on string
# Out:
# True

# %%
strq = "Data "
strq * 3
# Out:
# 'Data Data Data '

# %% [markdown]
# ## Logical Operators
# The key logical operators are **and**, **or** & **not**

# %%
x = True
y = False

print(f'Logical AND operation for {x} and {y}:- ',x  and  y)  #  True  if  both  values  are  true
print(f'Logical OR operation for {x} or {y}:- ',x  or  y)  #  True  if  either  of  the  values  is  true
# The above can be extended using multiple logical operators
print(f'NOT operation upon {y}:- ',not  y)  #  True  if  operand  is  false and vice versa

# %% [markdown]
# # if conditional statement

# %% [markdown]
# * The _if_ statement evaluates an expression and executes a block of code on the condition that the expression is true.
# * In case the expression returns a False, the _if_ block-of-code is ignored.

# %%
a=8
if a>6:
    print(a,"is greater than 6.") # Indentation for the block-of-code
print("Independent statement") # Not indented

# %%
a = 25
b = 23


if a > b:
    print(f" {a} is greater than {b}")
elif a==b:
    print(f" {a} is equal to {b}")
else: 
    print(f" {a} is smaller than {b}")
# Out:
#  25 is greater than 23

# %% [markdown]
# #### Indentation refers to the spaces at the beginning of a
# code line. It is the standard syntax in control statements where Python uses indentation
# to indicate a block of code.

# %%
age=21
if age>=18:
    print("The person is above the age limit.") # executed if the expression is True
    print("The present age meets the condition") # Multiple code lines may be part of the if block

# %% [markdown]
# #### else may be included to account for alternate statements when if condition is false

# %%
x=5
if x==5:
    print('The if condition is true')
else: # when if condition is false
    print("The variable does not meet the condition")
    print('Else block-of-code got executed')

# %%
x=-23
if x>0:
    print('The given number is positive.')
else:
    print('The number may be negative.')
print("Out of if-else blocks") # will be executed regardless of the if condition outcome

# %% [markdown]
# ## Input function
# Obtain user input with a prompt

# %%
a=input('Enter your name:')

# %%
vehicle = input("Enter your choice of car") # prompt as argument

# %%
print(vehicle) # user input assigned to variable

# %%
type(vehicle) # input takes value as string by default

# %%
c=float(input('Enter your age:'))

d= int(float(input("Enter a number")))
print(d)
print(type(c))

# typecasting the user input is handy for numerical data
# Out:
# Enter your age: 55
# Enter a number 52
# 52
# <class 'float'>

# %%
print(c, type(c))

# %%
# elif can be used to check alternate conditions
country=input("Name of the country:")
if country==country.upper():
    print("The font entered is ALL CAPITAL")
elif country==country.lower():
    print("The font is all lowercase.")
elif country==country.capitalize():
    print("The font received is appropriate.")
else:
    print("Mixed case received")
print("One of the 4 blocks of code was executed.")

# %%
x=int(input("Enter a number"))
if(x>10):
    print('i am in if block')
elif(x==6):
# elif will help in checking more than 1 if condition
    print('i am in elif block')
elif(x==0):
    print('Zero number')
else:
    print('i am in else block')

# %%
# if... elif ... else
x =int(input('enter the number'))

if x>0:
    print("X is positive")
elif x<0:
    print("X is Negative")
    print('i am in elif block')
else:
    print("X is Zero")
    print('i am in else block')

print('outside of the loop')

# %% [markdown]
# ### Nested if
# An _if_ condition can be said to be nested when it is part of another _if_ block-of-code.
#
# The nested condition will only be tested when the parent _if_ expression happens to be true.

# %%
i = 10
if (i >= 10): #  parent if statement

    if (i < 15): # Nested if statement
        print("i is smaller than 15")
    # These expressions are tested only when the parent if returns True.
    if (i < 12):
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")

# %%
# bp range 120-129 accepted as normal
bp_systolic = int(input("Enter the current bp measurement:"))
condition = 120<=bp_systolic<=129
if condition == False: # out of normal range
    print("The blood pressure is out of the normal range.")
    if bp_systolic<90:
        print("A case of Low blood pressure")
        print("Advised to stay hydrated with regular intake of fluids")
    elif bp_systolic>=130:
        print("A case of high blood pressure")
        print("30 minutes of daily walk is recommended.")
    else:
        print("Not necessarily low bp but fluid intake to be increased")
else:
    print("Blood pressure is in the normal range")

# %%
# check if user entered number is multiple of 3 & 7 or not
# if number is multiple of 3 -? "It is multiple of 3"
# if number is multiple of 7 -> "It is multiple of 7"
# If number is multiple of 3 & 7 -> "It is multiple of 3 & 7"
# Else -? "It is neither multiple of 3 or 7"

n = int(input("Enter a number"))
'''
if(n%3 == n%7 ==0):
    print(f"{n} is multiple of both 3 & 7")
elif (n%3 ==0):
    print(f"{n} is multiple of 3")
elif(n%7 ==0):
    print(f"{n} is multiple of 7")
else:
    print(f"{n} is neither multiple of 3 or 7")
'''

if (n%3 == 0) | (n%7 == 0):
    if(n%3 == n%7 ==0):
        print(f"{n} is multiple of both 3 & 7")
    else:
        if (n%3 == 0):
            print(f"{n} is multiple of 3")
        else :
            print(f"{n} is multiple of 7")
else:
    print(f"{n} is neither multiple of 3 or 7")
# Out:
# Enter a number 42
# 42 is multiple of both 3 & 7

# %%
email = input("Enter your email address")



'''
if (len(email)>=20) :
    print("Length of email is greater than 20")
else: 
    print("Length of email is less than 20")
if (email[-10::] == "@gmail.com"):
    print("Email id ends with @gmail.com")
else: 
    print("Email id does not end with @gmail.com")
if (len(email)>=20) & (email[-10::] == "@gmail.com"):
    print(" Registration successful")
else:
    print("Registration not successful")

'''
if (len(email)>=20) & (email[-10::] == "@gmail.com"):
    print(" Registration successful")
else:  
    if(len(email)<20):
        print("Length of email is less than 20")
    elif (email[-10::] != "@gmail.com")
        print("Email id does not end with @gmail.com")
# Out:
# Enter your email address asdf@gmail.com
# Length of email is less than 20
# Email id ends with @gmail.com
# Registration not successful

# %% [markdown]
# # Packages

# %% [raw]
# Package is a cluster which can hold certain functionalities handy for different operations. In Python, we have many builtin packages which we find use for. Some examples are numpy, pandas, matplotlib.
#
# Packages contains modules in the form of python files (.py). Each module contains functionalities, classes and its objects.

# %% [markdown]
# # Datetime Module

# %% [raw]
# In Python, date and time are not data types of their own, but a module named datetime can be imported to work with the date as well as time. Python Datetime module comes built into Python, so there is no need to install it externally.

# %%
import datetime
datetime.__file__  # locate the module
# Out:
# 'C:\\Users\\USER\\anaconda3\\Lib\\datetime.py'

# %% [raw]
# 1)date – An idealized naive date, assuming the current Gregorian calendar always was, and always will be, in effect. Its attributes are year, month and day.
#
# 2)time – An idealized time, independent of any particular day, assuming that every day has exactly 24*60*60 seconds. Its attributes are hour, minute, second, microsecond.
#
# 3)datetime – Its a combination of date and time along with the attributes year, month, day, hour, minute, second, microsecond.
#
# 4)timedelta – A duration expressing the difference between two date, time, or datetime instances. The default gap in time is expressed in days but can go up to microsecond resolution.

# %%
from datetime import date, datetime, time

# %% [raw]
# Dates can be picked from the past or the future and assigned to a variable.

# %%
my_date = date(1930, 9, 13) ## Date creation with year,month,day as arguments

# %%
my_date # returns a datetime.date variable
# Out:
# datetime.date(1930, 9, 13)

# %%
# Getting today's date
today1 = date.today()

print("Today's date is", today1)
# Out:
# Today's date is 2026-02-05

# %%
today1.weekday()
# date.weekday gives output between 0-6
# date.isoweekday gives output between 1-7
# Days start from Monday and end on Sunday
# Out:
# 3

# %%
today1.isoweekday()
# Out:
# 4

# %%
# Get Today’s Year, Month, and Date

print("Current year:", today1.year)
print("Current month:", today1.month)
print("Current day:", today1.day)
# Out:
# Current year: 2026
# Current month: 2
# Current day: 5

# %%
from datetime import datetime as dt
date2  = dt.now()
date2
# Out:
# datetime.datetime(2026, 2, 5, 17, 6, 1, 158786)

# %%
print(date2.month)
print(date2.year)
print(date2.day)
# Out:
# 2
# 2026
# 5

# %%
# Get date from datetime sub module
from datetime import datetime as dt

# %%
at_present=dt.now()

# %%
at_present
# Out:
# datetime.datetime(2026, 2, 5, 17, 6, 35, 181538)

# %%
dt.date(at_present) # Extract date alone
# Out:
# datetime.date(2026, 2, 5)

# %%
at_present.day
# Out:
# 5

# %%
at_present.year
# Out:
# 2026

# %% [raw]
# # Attributes can be extracted down to the microsecond for a given variable
# # It is also possible to import time as a submodule by itself.

# %%
# Timedelta function demonstration

from datetime import timedelta, date

current_date = dt.now()

# Calculating future dates for 730 days
future_date_after_2yrs = current_date + timedelta(days=730)
future_date_after_2yrs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Timedelta function demonstration
#       3 from datetime import timedelta, date
# ----> 5 current_date = dt.now()
#       7 # Calculating future dates for 730 days
#       8 future_date_after_2yrs = current_date + timedelta(days=730)
#
# NameError: name 'dt' is not defined

# %%
from datetime import timedelta

d1 = date(2035,3,23)
d2 = date.today()

print(d2-d1, "the difference will be -ve")
d1-d2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from datetime import timedelta
# ----> 3 d1 = dt(2035,3,23)
#       4 d2 = date.today()
#       6 print(d2-d1, "the difference will be -ve")
#
# NameError: name 'dt' is not defined

# %%
## Task:- Calculate your age after 5000 days.
##The output should be in years.

# %%
dob = date(1993,9,9)
today = date.today()

today_5000 = today +timedelta(days = 5000)
today_5000 - dob
# Out:
# datetime.timedelta(days=16837)

# %% [markdown]
# # Data Structures of Python

# %% [markdown]
# ## List

# %% [raw]
# 1)	List is a sequence of items known for its flexibility.
# 2)	Different data types such as integer, float and string items can be held by a single list.
# 3) The sequence implies that items can be extracted by indexing.

# %%
# Empty list
blank1=[]
blank2 = list() # using list function

# %%
print(blank1,type(blank1))

# %%
# A list can consist purely of numbers
prime_nos = [1,2,3,5,7,11,13,17,19]
print(prime_nos)

# %%
# or we may be dealing with strings
home_decor = ['curtains','artifacts','paintings','wallpaper']
home_decor

# %%
# However, a deviation from the datatype may go unidentified..
animals = ['Zebra','Lion',49,'Weasel',-9.108,True,'Mongoose']
animals # as the list will accept heterogenous data

# %% [raw]
# As you did with singular variables, try the len() and type() functions with the above lists.

# %% [markdown]
# ### List Indexing and  Slicing

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' ,
          'seven' , 'eight']

# %%
mylist[6]

# %%
mylist[3:7] # slicing from location 3 to 7 excluding the last value

# %%
# Default step is 1
mylist[0:7:3] # Slicing with a step

# %%
# Direct replacement possible
animals[4] = 'Elephant' # indexing an item to reassign
animals

# %% [markdown]
# ### Add , Remove & Change Items

# %%
print("Before:",mylist) # existing list

# %%
mylist.append('nine')
#  Add  an  item  to  the  end  of  the  list
print("After:",mylist)

# %% [markdown]
# #### A function applied to a list modifies the structure instantaneously.

# %%
mylist.insert(3,'ten')
#  Add  item  at  index  location  3
mylist

# %%
mylist.extend([56,184,339,40])
#Add multiple elements at a time at end of list
mylist

# %%
mylist.pop(8)  #  Remove by location
mylist

# %%
mylist.pop()  # removes last element by default

# %%
mylist.remove('one')  #  Remove by item
mylist

# %%
del  mylist[7]  #  Remove  item  at  index  location  7
mylist

# %%
mylist.clear() # Emptying a list
mylist

# %%
del mylist # Delete entire list

# %% [raw]
# If deletion is successful, calling the list will throw up an error as the kernel no longer identifies it.

# %% [markdown]
# ### Join Lists by Concatenation

# %%
minerals = ['Zinc', 'Calcium', 'Potassium', 'Iron']
vitamins = ['Ascorbic acid', 'Thaimine', 'Niacin', 'Riboflavin']
print(minerals,"\n",vitamins)
# Out:
# ['Zinc', 'Calcium', 'Potassium', 'Iron']
#  ['Ascorbic acid', 'Thaimine', 'Niacin', 'Riboflavin']

# %%
body_needs = minerals + vitamins # Join two lists by '+' operator
body_needs
# Out:
# ['Zinc',
#  'Calcium',
#  'Potassium',
#  'Iron',
#  'Ascorbic acid',
#  'Thaimine',
#  'Niacin',
#  'Riboflavin']

# %% [markdown]
# ### List Membership

# %%
# Checking for presence of an item within the list

# %%
"Calcium" in vitamins
# Out:
# False

# %%
"Calcium" in body_needs
# Out:
# True

# %% [markdown]
# ### Reverse & Sort List

# %%
# reverse will reverse the elements in place
# [::-1] will only print the reversed elements but it won't change the original list

list1 = [5,7,2,9,1,0,42]
print(list1)
list1.reverse()
print(list1)
# Out:
# [5, 7, 2, 9, 1, 0, 42]
# [42, 0, 1, 9, 2, 7, 5]

# %%
list1[::-1]  # Reversing by slicing
# [::-1] will only print the reversed elements but it won't change the original list
# Out:
# [5, 7, 2, 9, 1, 0, 42]

# %%
# [::-1] will only print the reversed elements but it won't change the original list

list1
# Out:
# [42, 0, 1, 9, 2, 7, 5]

# %%
body_needs.sort()
print(body_needs)  # sorting strings
# Out:
# ['Ascorbic acid', 'Calcium', 'Iron', 'Niacin', 'Potassium', 'Riboflavin', 'Thaimine', 'Zinc']

# %%
mylist3  =  [9,5,2,99,120,88,34,45,12,48,26]
mylist3.sort()	# Sort list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 26, 34, 45, 48, 88, 99, 120]

# %%
mylist3.sort(reverse=True)	#  Sort  list  in  descending  order
mylist3

# %% [raw]
# Use mixed data types as items and see how sorting works.

# %% [markdown]
# ### All / Any

# %% [raw]
# The all() method returns:
# True if and only if all elements in a list are True; otherwise the output is False.
# The any() function returns:
# True if any single element in the list is True.

# %%
# Task:- Create a list of numbers ~ numlist. Try all(numlist) and any(numlist)


any(list1)
# Out:
# True

# %% [markdown]
# ## Tuples

# %% [raw]
# 1.	Tuple is similar to a list except that a tuple is immutable - we cannot change the elements of a tuple once assigned.
# 2.	When we do not want to change the data over time, tuple is a preferred data type.
# 3.	Iterating over the elements of a tuple is faster compared to iterating over a list.

# %%
tup1 = ()	# Empty tuple

# %%
type(tup1)

# %%
measures = (10.771,30.6,60.89)	# tuple of float numbers

# %%
mixed  =  ('Data',  25  ,(50,  100),(150,  90))	#  Nested  tuples

# %% [markdown]
# ### Tuple Indexing
# The sequence in a tuple stays intact once created.

# %%
tup2 = (5,8,'apple', 10, True)

# %%
tup2[1]

# %%
tup2[0:3]  #  slicing operations similar to lists

# %%
tup8=('Data', 25, [50, 100], [150, 90], ['Aparna', 'Bella'], (99, 22, 33))

# %%
tup8[4][1] # indexing nested items

# %%
tup8[5][2]

# %% [markdown]
# #### Immutability implies no function can modify the structure. Therefore, addition or removal of items is _not_ possible.

# %%
del  tup8[0]
#  Tuples  are  immutable  which  means  we  can't  DELETE  tuple  items

# %%
mixed[0]  =  1
#  Tuples  are  immutable  which  means  we  can't  CHANGE  tuple  items

# %%
print("Existing tuple:",measures)
del measures
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 print("Existing tuple:",measures)
#       2 del measures
#
# NameError: name 'measures' is not defined

# %%
print("After deletion:",measures)

# %% [markdown]
# ### Count & Index
# These are among the few functions are common to lists and tuples.

# %%
scores = (75,38,77,90,75,86,60,92,75,36,82,84,75,75)
scores

# %%
scores.count(75) # no. of occurrences of a given item through the tuple

# %%
scores.index(75) # locate the position of an item

# %% [raw]
# In case of multiple occurrences of an item, index() locates the very first instance in the sequence.

# %% [markdown]
# ### Sorting

# %%
scores.sort()  # sort() cannot work for tuples since it is designed to modify the structure

# %%
sorted(scores)	# Returns a structure in ascending order
# What else do you notice about the output?

# %% [raw]
# Try using the reverse argument in sorted() switching it to True.

# %% [markdown]
# ## Sets

# %% [raw]
# 1)	Unordered collection of items. A sequence is non-existent in a set.
# 2)	Set elements are unique. Duplicate elements are not allowed.

# %%
myset = set() # Creating an empty set
print(type(myset))

# %%
numeric = {2,1,2,6,2,4,3,3,2,3,5}
numeric	# set ignores any presence of duplicates

# %%
greeting  =  {"Namaste","Hello", "Hola",  ("Bueno Dias", "Salaam",  "Suprabhat")}
greeting

# %%
greeting[0] # error confirms no sequence to index

# %%
'Hola' in greeting # Check for presence of item in the set

# %% [markdown]
# ### Set functions

# %%
news = {"Business","Politics"}

# %%
news.add("Sports") # addition of a single item
print(news)

# %%
sections = ["Entertainment","Lifestyle","Advertising"]
news.update(sections)
news # mutiple items added

# %%
news.add(250)
print(news)
news.remove(250)
news.discard("Lifestyle")

# %% [raw]
# Try different examples and see if you can identify the difference between remove() and discard()

# %% [markdown]
# #### While we can modify the set, a given set item is not replaceable. In other words, sets are mutable but set items are not.

# %%
news.clear() # Delete all items within the set
news

# %%
del news # Delete the set object
print(news)

# %% [markdown]
# ### Set Operations

# %%
A  =  {1,2,3,4,5}
B  =  {4,5,6,7,8}
C  =  {8,9,10}

# %%
A.union(B)  #  Union combines all items from the sets

# %%
B.union(A) # same effect as above

# %%
A.union(B,C)	#  Union  of  A,  B  and  C

# %%
A.intersection(B)  # common items

# %%
A.difference(B)  #  Difference  of sets i.e. set of elements that are only in A but not in B

# %% [markdown]
# ## Dictionary

# %% [raw]
# 1) Dictionary is a mutable data type in Python.
# 2) A python dictionary is a collection of key and value pairs.
# 3) Keys must be unique in a dictionary, duplicate values are allowed

# %%
initial_dict = dict() # empty dictionary
blank = {}

# %%
type(blank)

# %%
foods = {"A":"Spinach","B":"Peas","C":"Orange"}
foods

# %%
foods.keys()  # Keys in a dictionary must be unique

# %%
foods.values()

# %%
foods.items()

# %%
v=[0,1,2,3,[8,{5:[67,89,90,{'area':'Southeast','city':'Bangalore'}]}]]

## Extract Bangalore

# %%
v[4][1][5][3]['city']

# %% [markdown]
# ### Functions: Add, Remove & Change Items

# %%
mydict1 = {'Name':"Data Center" , 'ID': 12345 , 'DOB': 1991 ,
           'Address' : 'Helsinki'}
mydict1

# %%
mydict1.update({'key':'value1'})

# %%
mydict1['Job'] = 'Analyst' # Adding items in the dictionary
mydict1

# %%
mydict1

# %%
mydict1['DOB'] = 1992	# Changing Dictionary Items

mydict1

# %%
mydict1

# %%
mydict1.pop('Job')  #  Removing  items  in  the  dictionary  using  Pop  method
mydict1

# %%
del mydict1['ID'] # Removing item using del method
mydict1

# %%
mydict1.clear() # Delete all items of the dictionary

# %%
del mydict1 # Delete the dictionary object
mydict1
