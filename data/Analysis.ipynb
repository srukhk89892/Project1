# %%
for i in range(10):
    print("Hello World1")
# Out:
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
# Hello World1
